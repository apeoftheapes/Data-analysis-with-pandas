# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, date
import matplotlib.ticker as mticker


df = pd.read_csv('2023_04_04_intel (1).csv')
df['date'] = pd.to_datetime(df['date'])

# df = df[(df['time'] >= datetime.fromisoformat('2023-04-01')) & (df['time'] <= datetime.fromisoformat('2023-11-30'))]
df = df[df['date'] < pd.to_datetime('2023-11-30')]
x = df['date']
y1 = df['supply']
y2 = df['price']

fig, ax1 = plt.subplots(figsize=(10,4))

ax2 = ax1.twinx()
ax1.plot(x, y1, '-', color = (208/255, 208/255, 208/235), zorder = 10)
ax2.plot(x, y2, '-', color = (36/255, 251/255, 169/255),zorder = 1)
#ax1.fill_between(x, y1, color = (208/255, 208/255, 208/235), alpha = 0.2)



ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
fig.autofmt_xdate()

ax1.set_ylabel('Supply last active 1+ years ago, %', color= (208/255, 208/255, 208/235))
ax2.set_ylabel('BTC/USD', color = (36/255, 251/255, 169/255))

#format number to a more readable form
def human_format(num):
    magnitude = 0
    while abs(num) >= 100:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'bn', 'T', 'TT'][magnitude])

ticks_loc = ax1.get_yticks().tolist();
ax1.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc));
ax1.set_yticklabels([f'{human_format(x)}%' for x in ticks_loc]);
ticks_loc = ax2.get_yticks().tolist();
ax2.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc));
ax2.set_yticklabels([f'${x:.0f}' for x in ticks_loc]);

# %%
df
# Out:
#          date  supply  price
# 0  2023-11-01  68.235  35421
# 1  2023-11-02  68.228  34934
# 2  2023-11-03  68.236  34740
# 3  2023-11-04  68.754  35070
# 4  2023-11-05  68.782  35053
# 5  2023-11-06  68.784  35032
# 6  2023-11-07  68.800  35448
# 7  2023-11-08  68.840  35708
# 8  2023-11-09  68.968  36718
# 9  2023-11-10  69.070  37327
# 10 2023-11-11  69.226  37128
# 11 2023-11-12  69.363  37057
# 12 2023-11-13  69.436  36534
# 13 2023-11-14  69.563  35534
# 14 2023-11-15  69.602  37964
# 15 2023-11-16  69.699  36208
# 16 2023-11-17  69.810  36549
# 17 2023-11-18  70.236  36580
# 18 2023-11-19  70.257  37420
# 19 2023-11-20  70.286  37485
# 20 2023-11-21  70.292  35969
# 21 2023-11-22  70.357  37459
# 22 2023-11-23  70.431  37289
# 23 2023-11-24  70.442  37727
# 24 2023-11-25  70.465  37803
# 25 2023-11-26  70.472  37484
# 26 2023-11-27  70.494  37269
# 27 2023-11-28  70.521  37793
# 28 2023-11-29  70.540  37827

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, date
import matplotlib.ticker as mticker


df = pd.read_csv('2023_04_04_intel (1).csv')
df['date'] = pd.to_datetime(df['date'])

# df = df[(df['time'] >= datetime.fromisoformat('2023-04-01')) & (df['time'] <= datetime.fromisoformat('2023-11-30'))]
df = df[df['date'] < pd.to_datetime('2023-11-30')]
x = df['date']
y1 = df['price']
y2 = df['supply']


fig, ax1 = plt.subplots(figsize=(10,4))

ax2 = ax1.twinx()
ax1.plot(x, y1, '-', color = (208/255, 208/255, 208/235), zorder = 10)
ax2.plot(x, y2, '-', color = (36/255, 251/255, 169/255),zorder = 1)
ax1.fill_between(x, y1, color = (208/255, 208/255, 208/235), alpha = 0.2)



ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
fig.autofmt_xdate()

ax1.set_ylabel('BTC/USD', color= (208/255, 208/255, 208/235))
ax2.set_ylabel('Supply last active 1+ years ago, %', color = (36/255, 251/255, 169/255))

#format number to a more readable form
def human_format(num):
    magnitude = 0
    while abs(num) >= 100:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'bn', 'T', 'TT'][magnitude])

ticks_loc = ax2.get_yticks().tolist();
ax2.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc));
ax2.set_yticklabels([f'{human_format(x)}%' for x in ticks_loc]);
ticks_loc = ax1.get_yticks().tolist();
ax1.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc));
ax1.set_yticklabels([f'${x:.0f}' for x in ticks_loc]);

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, date
import matplotlib.ticker as mticker


df = pd.read_csv('2023_04_04_intel (1).csv')
df['date'] = pd.to_datetime(df['date'])

# df = df[(df['time'] >= datetime.fromisoformat('2023-04-01')) & (df['time'] <= datetime.fromisoformat('2023-11-30'))]
df = df[df['date'] < pd.to_datetime('2023-11-30')]
x = df['date']
y1 = df['price']
y2 = df['supply']


fig, ax1 = plt.subplots(figsize=(10,4))

ax2 = ax1.twinx()
ax1.plot(x, y1, '-', color = (208/255, 208/255, 208/235), zorder = 10)
ax2.plot(x, y2, '-', color = (36/255, 251/255, 169/255),zorder = 1)
#ax1.fill_between(x, y1, color = (208/255, 208/255, 208/235), alpha = 0.2)



ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
fig.autofmt_xdate()

ax1.set_ylabel('BTC/USD', color= (208/255, 208/255, 208/235))
ax2.set_ylabel('Supply last active 1+ years ago, %', color = (36/255, 251/255, 169/255))

#format number to a more readable form
def human_format(num):
    magnitude = 0
    while abs(num) >= 100:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'bn', 'T', 'TT'][magnitude])

ticks_loc = ax2.get_yticks().tolist();
ax2.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc));
ax2.set_yticklabels([f'{human_format(x)}%' for x in ticks_loc]);
ticks_loc = ax1.get_yticks().tolist();
ax1.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc));
ax1.set_yticklabels([f'${x:.0f}' for x in ticks_loc]);
